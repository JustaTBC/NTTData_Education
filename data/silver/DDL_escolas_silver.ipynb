# %%
# %sql
CREATE TABLE IF NOT EXISTS nttdataeducacao.bronze.escolas_bronz
(
    ano INT,
    regiao STRING,
    uf STRING,
    cod_munic STRING,
    nome_munic STRING,
    cod_entid STRING,
    nome_entid STRING,
    localizacao STRING,
    dependencia STRING,
    total_educ_inf DOUBLE,
    creche DOUBLE,
    pre_escola DOUBLE,
    total_ens_fund DOUBLE,
    anos_iniciais DOUBLE,
    anos_finais DOUBLE,
    fundamental_1 DOUBLE,
    fundamental_2 DOUBLE,
    fundamental_3 DOUBLE,
    fundamental_4 DOUBLE,
    fundamental_5 DOUBLE,
    fundamental_6 DOUBLE,
    fundamental_7 DOUBLE,
    fundamental_8 DOUBLE,
    fundamental_9 DOUBLE,
    total_ensino_medio DOUBLE,
    medio_1 DOUBLE,
    medio_2 DOUBLE,
    medio_3 DOUBLE,
    medio_4 DOUBLE,
    nao_seriado DOUBLE
)
USING DELTA;
